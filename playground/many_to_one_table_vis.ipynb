# %%
import pandas as pd
import numpy as np
import json

# %%
with open('adv_examples/many-to-one/adv_gen_l_inf_2.json', 'r') as f:
    data = json.loads(f.read())
    
with open('models/many-to-one/model_info.json', 'r') as f:
    originals = json.loads(f.read())

    
metrics = [
    "R2",
    "RMSE",
    "MAE",
    "MAPE",
]

# %%
rows = []
for dataset in data.keys():
    for model_name in data[dataset].keys():
        for metric in metrics:
            rows.append((dataset,model_name,metric))
            

columns = [
    ('Original',''), \
    ('FGSM', '0.1'), ('FGSM', '0.05'), ('FGSM', '0.025'), ('FGSM', '0.01'), \
    ('PGD', '0.025 | 0.01'), ('PGD', '0.025 | 0.025'), ('PGD', '0.01 | 0.01'), ('PGD', '0.01 | 0.025')
]

row_list = pd.MultiIndex.from_tuples(rows)
col_list = pd.MultiIndex.from_tuples(columns)

A = pd.DataFrame(index = row_list, columns = col_list)

# %%
for dataset in originals.keys():
    for model_name in originals[dataset].keys():
        for metric in metrics:
                    A.loc[(dataset, model_name, metric)][('Original', '')] = round(originals[dataset][model_name][metric] ,2)

# %%
for dataset in data.keys():
    for model_name in data[dataset].keys():
        for adv_attack in data[dataset][model_name].keys():
            for setting in data[dataset][model_name][adv_attack].keys():
                parsed_setting = setting.replace('epsilon=', '').replace('alpha=', '')
                for metric in metrics:
                    A.loc[(dataset, model_name, metric)][(adv_attack, parsed_setting)] = data[dataset][model_name][adv_attack][setting]["metrics"][metric]

# %%
A.head(50)
# Out:
#                                                               Original  \
#
# Electricity Transformer Data - 15 min Single Layer LSTM  R2       0.99
#                                                          RMSE     0.35
#                                                          MAE      0.25
#                                                          MAPE     4.94
#                                       Double Layer LSTM  R2       0.99
#                                                          RMSE     0.32
#                                                          MAE      0.22
#                                                          MAPE     4.34
#                                       Bidirectional LSTM R2       0.99
#                                                          RMSE     0.32
#                                                          MAE      0.23
#                                                          MAPE     4.32
#                                       CNN1D              R2       0.98
#                                                          RMSE     0.53
#                                                          MAE      0.39
#                                                          MAPE      7.8
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2       0.95
#                                                          RMSE   449.74
#                                                          MAE    321.11
#                                                          MAPE    17.21
#                                       Double Layer LSTM  R2       0.95
#                                                          RMSE   433.64
#                                                          MAE    306.83
#                                                          MAPE    19.19
#                                       Bidirectional LSTM R2       0.95
#                                                          RMSE   429.81
#                                                          MAE    305.38
#                                                          MAPE    15.65
#                                       CNN1D              R2       0.95
#                                                          RMSE   448.97
#                                                          MAE    325.54
#                                                          MAPE    19.32
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2       0.95
#                                                          RMSE    19.57
#                                                          MAE     10.58
#                                                          MAPE    26.98
#                                       Double Layer LSTM  R2       0.95
#                                                          RMSE    19.67
#                                                          MAE     10.77
#                                                          MAPE    33.26
#                                       Bidirectional LSTM R2       0.95
#                                                          RMSE    19.69
#                                                          MAE     10.79
#                                                          MAPE    34.46
#                                       CNN1D              R2       0.94
#                                                          RMSE    21.56
#                                                          MAE     12.59
#                                                          MAPE    46.36
# Solar Generation - EnerjiSA           Single Layer LSTM  R2       0.99
#                                                          RMSE    12.86
#
#                                                                   FGSM  \
#                                                                    0.1
# Electricity Transformer Data - 15 min Single Layer LSTM  R2     -1.737
#                                                          RMSE     6.06
#                                                          MAE      6.05
#                                                          MAPE   116.14
#                                       Double Layer LSTM  R2     -1.334
#                                                          RMSE      5.6
#                                                          MAE      5.58
#                                                          MAPE   108.46
#                                       Bidirectional LSTM R2     -1.274
#                                                          RMSE     5.52
#                                                          MAE      5.51
#                                                          MAPE   105.03
#                                       CNN1D              R2     -2.379
#                                                          RMSE     6.73
#                                                          MAE      6.26
#                                                          MAPE   119.37
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2      0.174
#                                                          RMSE   1795.6
#                                                          MAE   1671.08
#                                                          MAPE   129.43
#                                       Double Layer LSTM  R2     -0.147
#                                                          RMSE  2115.27
#                                                          MAE   1839.13
#                                                          MAPE   181.15
#                                       Bidirectional LSTM R2      0.181
#                                                          RMSE  1787.95
#                                                          MAE   1637.23
#                                                          MAPE   123.28
#                                       CNN1D              R2      0.336
#                                                          RMSE  1609.77
#                                                          MAE   1388.14
#                                                          MAPE    73.57
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2     -0.052
#                                                          RMSE    91.29
#                                                          MAE     82.29
#                                                          MAPE   240.88
#                                       Double Layer LSTM  R2     -0.155
#                                                          RMSE    95.66
#                                                          MAE      89.6
#                                                          MAPE   318.95
#                                       Bidirectional LSTM R2     -0.107
#                                                          RMSE    93.67
#                                                          MAE     87.66
#                                                          MAPE   314.26
#                                       CNN1D              R2     -0.909
#                                                          RMSE   123.01
#                                                          MAE     116.0
#                                                          MAPE   449.96
# Solar Generation - EnerjiSA           Single Layer LSTM  R2      0.216
#                                                          RMSE   121.95
#
#                                                                         \
#                                                                   0.05
# Electricity Transformer Data - 15 min Single Layer LSTM  R2      0.252
#                                                          RMSE     3.17
#                                                          MAE      3.16
#                                                          MAPE    60.39
#                                       Double Layer LSTM  R2      0.354
#                                                          RMSE     2.94
#                                                          MAE      2.93
#                                                          MAPE    56.01
#                                       Bidirectional LSTM R2      0.373
#                                                          RMSE      2.9
#                                                          MAE      2.89
#                                                          MAPE    54.66
#                                       CNN1D              R2      0.114
#                                                          RMSE     3.45
#                                                          MAE      3.24
#                                                          MAPE    60.98
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2      0.635
#                                                          RMSE  1192.95
#                                                          MAE    1081.7
#                                                          MAPE    79.73
#                                       Double Layer LSTM  R2      0.441
#                                                          RMSE  1477.42
#                                                          MAE   1272.24
#                                                          MAPE   116.04
#                                       Bidirectional LSTM R2      0.615
#                                                          RMSE  1226.29
#                                                          MAE   1106.04
#                                                          MAPE    81.14
#                                       CNN1D              R2      0.637
#                                                          RMSE  1190.17
#                                                          MAE   1049.14
#                                                          MAPE    62.34
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2      0.618
#                                                          RMSE    55.02
#                                                          MAE     49.28
#                                                          MAPE   143.83
#                                       Double Layer LSTM  R2      0.595
#                                                          RMSE    56.68
#                                                          MAE     52.16
#                                                          MAPE   182.15
#                                       Bidirectional LSTM R2      0.611
#                                                          RMSE    55.49
#                                                          MAE     50.84
#                                                          MAPE   178.14
#                                       CNN1D              R2      0.318
#                                                          RMSE    73.51
#                                                          MAE     69.01
#                                                          MAPE   253.91
# Solar Generation - EnerjiSA           Single Layer LSTM  R2      0.724
#                                                          RMSE    72.39
#
#                                                                                \
#                                                                 0.025    0.01
# Electricity Transformer Data - 15 min Single Layer LSTM  R2     0.779   0.944
#                                                          RMSE    1.72    0.87
#                                                          MAE      1.7    0.83
#                                                          MAPE    32.6   15.99
#                                       Double Layer LSTM  R2      0.81   0.952
#                                                          RMSE     1.6     0.8
#                                                          MAE     1.58    0.76
#                                                          MAPE   30.11   14.65
#                                       Bidirectional LSTM R2     0.815   0.953
#                                                          RMSE    1.58    0.79
#                                                          MAE     1.56    0.76
#                                                          MAPE   29.47   14.37
#                                       CNN1D              R2     0.686   0.899
#                                                          RMSE    2.05    1.16
#                                                          MAE     1.94    1.07
#                                                          MAPE   36.56   20.66
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2     0.831   0.912
#                                                          RMSE   812.3  585.76
#                                                          MAE   710.75  477.62
#                                                          MAPE   48.67   29.64
#                                       Double Layer LSTM  R2      0.76   0.898
#                                                          RMSE  968.36  629.55
#                                                          MAE   825.71  515.52
#                                                          MAPE   67.41   37.49
#                                       Bidirectional LSTM R2     0.826   0.915
#                                                          RMSE  823.86  576.94
#                                                          MAE   723.97  474.39
#                                                          MAPE   49.49   29.14
#                                       CNN1D              R2     0.804   0.898
#                                                          RMSE  874.36  631.58
#                                                          MAE   771.21  533.99
#                                                          MAPE   48.05   33.21
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2     0.833   0.917
#                                                          RMSE   36.36   25.66
#                                                          MAE    31.01   19.15
#                                                          MAPE    92.0   56.71
#                                       Double Layer LSTM  R2     0.827   0.915
#                                                          RMSE    37.0   25.88
#                                                          MAE    32.09    19.5
#                                                          MAPE  110.98   65.91
#                                       Bidirectional LSTM R2     0.833   0.917
#                                                          RMSE   36.38   25.67
#                                                          MAE    31.33   19.16
#                                                          MAPE  108.49   65.13
#                                       CNN1D              R2     0.724   0.879
#                                                          RMSE   46.78   30.96
#                                                          MAE    42.28   24.98
#                                                          MAPE  152.31    88.6
# Solar Generation - EnerjiSA           Single Layer LSTM  R2     0.901   0.968
#                                                          RMSE   43.31   24.79
#
#                                                                        PGD  \
#                                                               0.025 | 0.01
# Electricity Transformer Data - 15 min Single Layer LSTM  R2          0.967
#                                                          RMSE         0.66
#                                                          MAE          0.56
#                                                          MAPE        10.62
#                                       Double Layer LSTM  R2          0.964
#                                                          RMSE          0.7
#                                                          MAE          0.62
#                                                          MAPE        12.15
#                                       Bidirectional LSTM R2          0.966
#                                                          RMSE         0.67
#                                                          MAE          0.59
#                                                          MAPE         10.8
#                                       CNN1D              R2          0.923
#                                                          RMSE         1.02
#                                                          MAE          0.89
#                                                          MAPE        17.27
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2          0.912
#                                                          RMSE       584.75
#                                                          MAE        473.22
#                                                          MAPE        29.02
#                                       Double Layer LSTM  R2          0.899
#                                                          RMSE       628.99
#                                                          MAE        511.21
#                                                          MAPE        36.93
#                                       Bidirectional LSTM R2          0.915
#                                                          RMSE       575.66
#                                                          MAE        469.45
#                                                          MAPE        28.42
#                                       CNN1D              R2          0.899
#                                                          RMSE       626.65
#                                                          MAE         525.7
#                                                          MAPE        32.65
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2           0.92
#                                                          RMSE        25.22
#                                                          MAE         17.83
#                                                          MAPE        47.74
#                                       Double Layer LSTM  R2           0.92
#                                                          RMSE        25.19
#                                                          MAE         17.37
#                                                          MAPE        53.35
#                                       Bidirectional LSTM R2          0.921
#                                                          RMSE        25.02
#                                                          MAE         17.08
#                                                          MAPE        54.27
#                                       CNN1D              R2          0.885
#                                                          RMSE        30.17
#                                                          MAE         23.31
#                                                          MAPE        85.39
# Solar Generation - EnerjiSA           Single Layer LSTM  R2          0.968
#                                                          RMSE        24.67
#
#                                                                              \
#                                                               0.025 | 0.025
# Electricity Transformer Data - 15 min Single Layer LSTM  R2           0.863
#                                                          RMSE          1.35
#                                                          MAE           1.32
#                                                          MAPE         25.08
#                                       Double Layer LSTM  R2            0.85
#                                                          RMSE          1.42
#                                                          MAE           1.38
#                                                          MAPE         26.72
#                                       Bidirectional LSTM R2           0.861
#                                                          RMSE          1.37
#                                                          MAE           1.32
#                                                          MAPE         24.69
#                                       CNN1D              R2           0.566
#                                                          RMSE          2.41
#                                                          MAE           2.34
#                                                          MAPE         44.37
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2           0.835
#                                                          RMSE        801.47
#                                                          MAE         684.65
#                                                          MAPE         44.42
#                                       Double Layer LSTM  R2           0.761
#                                                          RMSE         966.2
#                                                          MAE         805.16
#                                                          MAPE         62.76
#                                       Bidirectional LSTM R2           0.831
#                                                          RMSE        813.06
#                                                          MAE         697.62
#                                                          MAPE         45.47
#                                       CNN1D              R2            0.79
#                                                          RMSE        904.74
#                                                          MAE         801.82
#                                                          MAPE          49.4
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2           0.852
#                                                          RMSE         34.26
#                                                          MAE          27.41
#                                                          MAPE         68.11
#                                       Double Layer LSTM  R2           0.858
#                                                          RMSE         33.51
#                                                          MAE          25.83
#                                                          MAPE         75.39
#                                       Bidirectional LSTM R2           0.866
#                                                          RMSE         32.61
#                                                          MAE          24.48
#                                                          MAPE         72.71
#                                       CNN1D              R2           0.759
#                                                          RMSE          43.7
#                                                          MAE          36.91
#                                                          MAPE        139.22
# Solar Generation - EnerjiSA           Single Layer LSTM  R2           0.904
#                                                          RMSE         42.69
#
#                                                                            \
#                                                               0.01 | 0.01
# Electricity Transformer Data - 15 min Single Layer LSTM  R2         0.967
#                                                          RMSE        0.66
#                                                          MAE         0.56
#                                                          MAPE       10.61
#                                       Double Layer LSTM  R2         0.964
#                                                          RMSE         0.7
#                                                          MAE         0.62
#                                                          MAPE       12.15
#                                       Bidirectional LSTM R2         0.966
#                                                          RMSE        0.67
#                                                          MAE         0.59
#                                                          MAPE        10.8
#                                       CNN1D              R2         0.891
#                                                          RMSE        1.21
#                                                          MAE          1.1
#                                                          MAPE       20.87
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2         0.912
#                                                          RMSE      584.83
#                                                          MAE       473.33
#                                                          MAPE       29.04
#                                       Double Layer LSTM  R2         0.898
#                                                          RMSE       629.4
#                                                          MAE       511.73
#                                                          MAPE       36.96
#                                       Bidirectional LSTM R2         0.915
#                                                          RMSE      575.83
#                                                          MAE       469.69
#                                                          MAPE       28.46
#                                       CNN1D              R2         0.895
#                                                          RMSE      640.99
#                                                          MAE       542.75
#                                                          MAPE       33.95
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2          0.92
#                                                          RMSE       25.24
#                                                          MAE        17.87
#                                                          MAPE       48.11
#                                       Double Layer LSTM  R2          0.92
#                                                          RMSE       25.24
#                                                          MAE        17.52
#                                                          MAPE       54.76
#                                       Bidirectional LSTM R2         0.921
#                                                          RMSE       25.03
#                                                          MAE        17.12
#                                                          MAPE       54.71
#                                       CNN1D              R2         0.881
#                                                          RMSE       30.72
#                                                          MAE        23.98
#                                                          MAPE       86.98
# Solar Generation - EnerjiSA           Single Layer LSTM  R2         0.968
#                                                          RMSE        24.7
#
#
#                                                               0.01 | 0.025
# Electricity Transformer Data - 15 min Single Layer LSTM  R2          0.863
#                                                          RMSE         1.35
#                                                          MAE          1.32
#                                                          MAPE        25.08
#                                       Double Layer LSTM  R2           0.85
#                                                          RMSE         1.42
#                                                          MAE          1.38
#                                                          MAPE        26.72
#                                       Bidirectional LSTM R2          0.861
#                                                          RMSE         1.37
#                                                          MAE          1.32
#                                                          MAPE        24.69
#                                       CNN1D              R2          0.492
#                                                          RMSE         2.61
#                                                          MAE          2.54
#                                                          MAPE        47.69
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2          0.836
#                                                          RMSE       800.48
#                                                          MAE        683.92
#                                                          MAPE        44.59
#                                       Double Layer LSTM  R2          0.761
#                                                          RMSE       966.33
#                                                          MAE        805.67
#                                                          MAPE        62.94
#                                       Bidirectional LSTM R2          0.831
#                                                          RMSE       812.16
#                                                          MAE        696.92
#                                                          MAPE         45.8
#                                       CNN1D              R2          0.779
#                                                          RMSE       927.69
#                                                          MAE        827.78
#                                                          MAPE        52.25
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2          0.852
#                                                          RMSE        34.26
#                                                          MAE         27.42
#                                                          MAPE        68.16
#                                       Double Layer LSTM  R2          0.858
#                                                          RMSE        33.54
#                                                          MAE          25.9
#                                                          MAPE        76.33
#                                       Bidirectional LSTM R2          0.866
#                                                          RMSE        32.62
#                                                          MAE         24.52
#                                                          MAPE        73.21
#                                       CNN1D              R2          0.755
#                                                          RMSE        44.03
#                                                          MAE         37.18
#                                                          MAPE       137.73
# Solar Generation - EnerjiSA           Single Layer LSTM  R2          0.903
#                                                          RMSE        42.98

# %%
A.to_excel('adversarial_attack_results.xlsx')

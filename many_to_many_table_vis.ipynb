# %%
import pandas as pd
import numpy as np
import json

# %%
with open('adv_examples/many-to-many/adv_gen_l_inf_2.json', 'r') as f:
    data = json.loads(f.read())
    
with open('models/many-to-many/model_info.json', 'r') as f:
    originals = json.loads(f.read())

    
metrics = [
    "R2",
    "RMSE",
    "MAE",
    "MAPE",
]

# %%
rows = []
for dataset in data.keys():
    for model_name in data[dataset].keys():
        for metric in metrics:
            rows.append((dataset,model_name,metric))
            

columns = [
    ('Original',''), \
    ('FGSM', '0.1'), ('FGSM', '0.05'), ('FGSM', '0.025'), ('FGSM', '0.01'), \
    ('PGD', '0.025 | 0.01'), ('PGD', '0.025 | 0.025'), ('PGD', '0.01 | 0.01'), ('PGD', '0.01 | 0.025')
]

row_list = pd.MultiIndex.from_tuples(rows)
col_list = pd.MultiIndex.from_tuples(columns)

A = pd.DataFrame(index = row_list, columns = col_list)

# %%
for dataset in originals.keys():
    for model_name in originals[dataset].keys():
        for metric in metrics:
                    A.loc[(dataset, model_name, metric)][('Original', '')] = round(originals[dataset][model_name][metric] ,2)

# %%
for dataset in data.keys():
    for model_name in data[dataset].keys():
        for adv_attack in data[dataset][model_name].keys():
            for setting in data[dataset][model_name][adv_attack].keys():
                parsed_setting = setting.replace('epsilon=', '').replace('alpha=', '')
                for metric in metrics:
                    A.loc[(dataset, model_name, metric)][(adv_attack, parsed_setting)] = data[dataset][model_name][adv_attack][setting]["metrics"][metric]

# %%
A.head(50)
# Out:
#                                                               Original  \
#
# Electricity Transformer Data - 15 min Single Layer LSTM  R2       0.93
#                                                          RMSE     0.98
#                                                          MAE      0.75
#                                                          MAPE    14.92
#                                       Double Layer LSTM  R2       0.95
#                                                          RMSE     0.81
#                                                          MAE      0.56
#                                                          MAPE    10.17
#                                       Bidirectional LSTM R2       0.95
#                                                          RMSE      0.8
#                                                          MAE      0.54
#                                                          MAPE    10.32
#                                       CNN1D              R2       0.94
#                                                          RMSE     0.92
#                                                          MAE      0.64
#                                                          MAPE    12.43
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2       0.63
#                                                          RMSE  1195.59
#                                                          MAE    883.58
#                                                          MAPE     68.7
#                                       Double Layer LSTM  R2        0.7
#                                                          RMSE   1090.0
#                                                          MAE    747.33
#                                                          MAPE    56.82
#                                       Bidirectional LSTM R2       0.65
#                                                          RMSE  1167.69
#                                                          MAE    848.21
#                                                          MAPE    70.76
#                                       CNN1D              R2       0.55
#                                                          RMSE   1317.6
#                                                          MAE   1007.95
#                                                          MAPE    77.23
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2       0.63
#                                                          RMSE    54.27
#                                                          MAE     33.09
#                                                          MAPE   122.09
#                                       Double Layer LSTM  R2       0.62
#                                                          RMSE    54.57
#                                                          MAE     33.22
#                                                          MAPE   118.24
#                                       Bidirectional LSTM R2       0.63
#                                                          RMSE    54.54
#                                                          MAE     33.03
#                                                          MAPE   121.03
#                                       CNN1D              R2       0.51
#                                                          RMSE    62.12
#                                                          MAE     39.54
#                                                          MAPE    152.3
# Solar Generation - EnerjiSA           Single Layer LSTM  R2        0.9
#                                                          RMSE    43.05
#
#                                                                   FGSM  \
#                                                                    0.1
# Electricity Transformer Data - 15 min Single Layer LSTM  R2     -1.403
#                                                          RMSE     5.68
#                                                          MAE      5.64
#                                                          MAPE   107.92
#                                       Double Layer LSTM  R2     -1.782
#                                                          RMSE     6.11
#                                                          MAE       6.0
#                                                          MAPE    116.1
#                                       Bidirectional LSTM R2     -2.061
#                                                          RMSE     6.41
#                                                          MAE      6.36
#                                                          MAPE    122.8
#                                       CNN1D              R2     -5.761
#                                                          RMSE     9.53
#                                                          MAE      8.69
#                                                          MAPE   161.58
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2     -0.476
#                                                          RMSE  2398.26
#                                                          MAE   1992.85
#                                                          MAPE   155.89
#                                       Double Layer LSTM  R2     -0.397
#                                                          RMSE   2333.5
#                                                          MAE   1864.41
#                                                          MAPE   162.02
#                                       Bidirectional LSTM R2     -0.383
#                                                          RMSE  2321.82
#                                                          MAE   1902.08
#                                                          MAPE   165.67
#                                       CNN1D              R2     -1.056
#                                                          RMSE  2830.58
#                                                          MAE   2335.42
#                                                          MAPE   215.73
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2     -0.669
#                                                          RMSE    115.1
#                                                          MAE    102.25
#                                                          MAPE   408.25
#                                       Double Layer LSTM  R2     -0.807
#                                                          RMSE   119.77
#                                                          MAE    103.18
#                                                          MAPE   410.79
#                                       Bidirectional LSTM R2       -0.4
#                                                          RMSE   105.42
#                                                          MAE     91.41
#                                                          MAPE   362.89
#                                       CNN1D              R2       -2.6
#                                                          RMSE   169.07
#                                                          MAE    139.28
#                                                          MAPE   671.59
# Solar Generation - EnerjiSA           Single Layer LSTM  R2      0.525
#                                                          RMSE    95.12
#
#                                                                         \
#                                                                   0.05
# Electricity Transformer Data - 15 min Single Layer LSTM  R2      0.218
#                                                          RMSE     3.24
#                                                          MAE      3.17
#                                                          MAPE    60.92
#                                       Double Layer LSTM  R2      0.096
#                                                          RMSE     3.48
#                                                          MAE      3.38
#                                                          MAPE    64.17
#                                       Bidirectional LSTM R2      0.087
#                                                          RMSE      3.5
#                                                          MAE      3.43
#                                                          MAPE    65.65
#                                       CNN1D              R2     -1.052
#                                                          RMSE     5.25
#                                                          MAE      4.76
#                                                          MAPE     90.8
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2     -0.076
#                                                          RMSE  2047.63
#                                                          MAE   1666.14
#                                                          MAPE   126.55
#                                       Double Layer LSTM  R2     -0.048
#                                                          RMSE  2020.92
#                                                          MAE    1567.2
#                                                          MAPE   127.59
#                                       Bidirectional LSTM R2      0.033
#                                                          RMSE  1941.77
#                                                          MAE   1556.95
#                                                          MAPE   129.96
#                                       CNN1D              R2     -0.564
#                                                          RMSE  2468.96
#                                                          MAE   2072.83
#                                                          MAPE   158.26
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2      0.131
#                                                          RMSE    83.05
#                                                          MAE     68.24
#                                                          MAPE   268.63
#                                       Double Layer LSTM  R2      0.042
#                                                          RMSE    87.21
#                                                          MAE     69.98
#                                                          MAPE   267.01
#                                       Bidirectional LSTM R2      0.225
#                                                          RMSE    78.44
#                                                          MAE      62.5
#                                                          MAPE   244.38
#                                       CNN1D              R2     -0.682
#                                                          RMSE   115.56
#                                                          MAE     94.64
#                                                          MAPE    409.1
# Solar Generation - EnerjiSA           Single Layer LSTM  R2      0.745
#                                                          RMSE     69.7
#
#                                                                         \
#                                                                  0.025
# Electricity Transformer Data - 15 min Single Layer LSTM  R2      0.686
#                                                          RMSE     2.05
#                                                          MAE      1.94
#                                                          MAPE    37.42
#                                       Double Layer LSTM  R2      0.677
#                                                          RMSE     2.08
#                                                          MAE      1.95
#                                                          MAPE    36.55
#                                       Bidirectional LSTM R2      0.683
#                                                          RMSE     2.06
#                                                          MAE      1.95
#                                                          MAPE    37.14
#                                       CNN1D              R2      0.253
#                                                          RMSE     3.17
#                                                          MAE      2.89
#                                                          MAPE     55.9
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2      0.246
#                                                          RMSE  1714.56
#                                                          MAE   1362.27
#                                                          MAPE   102.96
#                                       Double Layer LSTM  R2      0.286
#                                                          RMSE  1668.47
#                                                          MAE    1250.9
#                                                          MAPE    98.01
#                                       Bidirectional LSTM R2      0.318
#                                                          RMSE   1630.2
#                                                          MAE   1268.15
#                                                          MAPE   105.01
#                                       CNN1D              R2       -0.1
#                                                          RMSE  2071.08
#                                                          MAE   1718.84
#                                                          MAPE   125.51
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2      0.424
#                                                          RMSE    67.64
#                                                          MAE     50.25
#                                                          MAPE   195.94
#                                       Double Layer LSTM  R2      0.378
#                                                          RMSE    70.29
#                                                          MAE     51.42
#                                                          MAPE   191.91
#                                       Bidirectional LSTM R2      0.457
#                                                          RMSE    65.65
#                                                          MAE      47.3
#                                                          MAPE   182.69
#                                       CNN1D              R2     -0.041
#                                                          RMSE    90.91
#                                                          MAE     70.76
#                                                          MAPE   283.69
# Solar Generation - EnerjiSA           Single Layer LSTM  R2      0.834
#                                                          RMSE    56.18
#
#                                                                         \
#                                                                   0.01
# Electricity Transformer Data - 15 min Single Layer LSTM  R2      0.859
#                                                          RMSE     1.38
#                                                          MAE       1.2
#                                                          MAPE    23.47
#                                       Double Layer LSTM  R2       0.88
#                                                          RMSE     1.27
#                                                          MAE      1.08
#                                                          MAPE    19.84
#                                       Bidirectional LSTM R2      0.884
#                                                          RMSE     1.25
#                                                          MAE      1.07
#                                                          MAPE    20.21
#                                       CNN1D              R2      0.726
#                                                          RMSE     1.92
#                                                          MAE      1.72
#                                                          MAPE    33.16
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2      0.476
#                                                          RMSE  1429.15
#                                                          MAE   1096.78
#                                                          MAPE    83.88
#                                       Double Layer LSTM  R2       0.54
#                                                          RMSE  1339.71
#                                                          MAE    961.99
#                                                          MAPE    73.94
#                                       Bidirectional LSTM R2      0.512
#                                                          RMSE  1378.67
#                                                          MAE   1034.15
#                                                          MAPE    86.13
#                                       CNN1D              R2      0.274
#                                                          RMSE  1682.23
#                                                          MAE   1354.73
#                                                          MAPE     99.9
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2      0.558
#                                                          RMSE    59.22
#                                                          MAE     39.52
#                                                          MAPE   151.12
#                                       Double Layer LSTM  R2      0.539
#                                                          RMSE    60.53
#                                                          MAE     40.12
#                                                          MAPE   146.75
#                                       Bidirectional LSTM R2      0.566
#                                                          RMSE    58.68
#                                                          MAE     38.34
#                                                          MAPE   145.05
#                                       CNN1D              R2      0.271
#                                                          RMSE    76.08
#                                                          MAE     54.94
#                                                          MAPE   212.27
# Solar Generation - EnerjiSA           Single Layer LSTM  R2      0.878
#                                                          RMSE    48.18
#
#                                                                        PGD  \
#                                                               0.025 | 0.01
# Electricity Transformer Data - 15 min Single Layer LSTM  R2          0.869
#                                                          RMSE         1.33
#                                                          MAE          1.09
#                                                          MAPE        21.39
#                                       Double Layer LSTM  R2          0.889
#                                                          RMSE         1.22
#                                                          MAE           1.0
#                                                          MAPE        17.89
#                                       Bidirectional LSTM R2          0.896
#                                                          RMSE         1.18
#                                                          MAE          0.95
#                                                          MAPE        17.78
#                                       CNN1D              R2           0.83
#                                                          RMSE         1.51
#                                                          MAE          1.21
#                                                          MAPE         24.6
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2           0.48
#                                                          RMSE       1423.8
#                                                          MAE       1092.29
#                                                          MAPE        83.62
#                                       Double Layer LSTM  R2          0.538
#                                                          RMSE      1342.64
#                                                          MAE        965.24
#                                                          MAPE        74.52
#                                       Bidirectional LSTM R2          0.512
#                                                          RMSE      1378.92
#                                                          MAE        1033.8
#                                                          MAPE        86.36
#                                       CNN1D              R2          0.298
#                                                          RMSE       1654.5
#                                                          MAE       1332.08
#                                                          MAPE        97.83
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2          0.559
#                                                          RMSE        59.17
#                                                          MAE         39.28
#                                                          MAPE       149.43
#                                       Double Layer LSTM  R2          0.539
#                                                          RMSE         60.5
#                                                          MAE         40.01
#                                                          MAPE       145.89
#                                       Bidirectional LSTM R2          0.567
#                                                          RMSE        58.63
#                                                          MAE         38.15
#                                                          MAPE       143.78
#                                       CNN1D              R2          0.337
#                                                          RMSE        72.57
#                                                          MAE         51.17
#                                                          MAPE       203.26
# Solar Generation - EnerjiSA           Single Layer LSTM  R2          0.878
#                                                          RMSE        48.19
#
#                                                                              \
#                                                               0.025 | 0.025
# Electricity Transformer Data - 15 min Single Layer LSTM  R2           0.844
#                                                          RMSE          1.45
#                                                          MAE           1.11
#                                                          MAPE         20.43
#                                       Double Layer LSTM  R2           0.745
#                                                          RMSE          1.85
#                                                          MAE           1.67
#                                                          MAPE         30.56
#                                       Bidirectional LSTM R2           0.762
#                                                          RMSE          1.79
#                                                          MAE           1.61
#                                                          MAPE         30.08
#                                       CNN1D              R2           0.177
#                                                          RMSE          3.32
#                                                          MAE           3.02
#                                                          MAPE         55.93
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2           0.193
#                                                          RMSE       1773.71
#                                                          MAE        1410.13
#                                                          MAPE        107.98
#                                       Double Layer LSTM  R2           0.217
#                                                          RMSE       1747.49
#                                                          MAE        1322.48
#                                                          MAPE        105.31
#                                       Bidirectional LSTM R2           0.264
#                                                          RMSE       1693.36
#                                                          MAE        1324.13
#                                                          MAPE        111.34
#                                       CNN1D              R2          -0.213
#                                                          RMSE       2174.41
#                                                          MAE         1834.8
#                                                          MAPE        132.17
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2           0.437
#                                                          RMSE         66.88
#                                                          MAE           48.2
#                                                          MAPE        185.24
#                                       Double Layer LSTM  R2           0.385
#                                                          RMSE         69.86
#                                                          MAE          50.19
#                                                          MAPE        185.81
#                                       Bidirectional LSTM R2           0.466
#                                                          RMSE          65.1
#                                                          MAE          45.74
#                                                          MAPE        174.94
#                                       CNN1D              R2          -0.181
#                                                          RMSE         96.81
#                                                          MAE          76.96
#                                                          MAPE        310.67
# Solar Generation - EnerjiSA           Single Layer LSTM  R2           0.834
#                                                          RMSE         56.28
#
#                                                                            \
#                                                               0.01 | 0.01
# Electricity Transformer Data - 15 min Single Layer LSTM  R2         0.869
#                                                          RMSE        1.33
#                                                          MAE         1.09
#                                                          MAPE       21.39
#                                       Double Layer LSTM  R2         0.889
#                                                          RMSE        1.22
#                                                          MAE          1.0
#                                                          MAPE       17.86
#                                       Bidirectional LSTM R2         0.896
#                                                          RMSE        1.18
#                                                          MAE         0.95
#                                                          MAPE       17.77
#                                       CNN1D              R2         0.703
#                                                          RMSE         2.0
#                                                          MAE         1.76
#                                                          MAPE       34.07
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2         0.469
#                                                          RMSE      1439.1
#                                                          MAE      1105.81
#                                                          MAPE       84.58
#                                       Double Layer LSTM  R2         0.532
#                                                          RMSE     1350.85
#                                                          MAE       972.16
#                                                          MAPE       74.93
#                                       Bidirectional LSTM R2         0.502
#                                                          RMSE     1393.53
#                                                          MAE      1045.96
#                                                          MAPE       87.25
#                                       CNN1D              R2         0.254
#                                                          RMSE     1705.36
#                                                          MAE      1381.13
#                                                          MAPE      101.18
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2         0.559
#                                                          RMSE       59.17
#                                                          MAE        39.29
#                                                          MAPE       149.5
#                                       Double Layer LSTM  R2         0.539
#                                                          RMSE        60.5
#                                                          MAE        40.02
#                                                          MAPE      145.91
#                                       Bidirectional LSTM R2         0.567
#                                                          RMSE       58.63
#                                                          MAE        38.15
#                                                          MAPE      143.79
#                                       CNN1D              R2         0.248
#                                                          RMSE       77.27
#                                                          MAE        56.39
#                                                          MAPE      217.78
# Solar Generation - EnerjiSA           Single Layer LSTM  R2         0.878
#                                                          RMSE       48.19
#
#
#                                                               0.01 | 0.025
# Electricity Transformer Data - 15 min Single Layer LSTM  R2          0.844
#                                                          RMSE         1.45
#                                                          MAE           1.1
#                                                          MAPE        20.39
#                                       Double Layer LSTM  R2          0.747
#                                                          RMSE         1.84
#                                                          MAE          1.67
#                                                          MAPE        30.36
#                                       Bidirectional LSTM R2          0.764
#                                                          RMSE         1.78
#                                                          MAE          1.61
#                                                          MAPE        29.97
#                                       CNN1D              R2         -0.272
#                                                          RMSE         4.13
#                                                          MAE          3.89
#                                                          MAPE        71.82
# Metro Interstate Human Traffic Volume Single Layer LSTM  R2          0.188
#                                                          RMSE      1779.46
#                                                          MAE       1415.18
#                                                          MAPE       108.58
#                                       Double Layer LSTM  R2          0.218
#                                                          RMSE      1746.09
#                                                          MAE       1319.71
#                                                          MAPE       104.76
#                                       Bidirectional LSTM R2          0.262
#                                                          RMSE      1696.06
#                                                          MAE       1323.33
#                                                          MAPE       111.71
#                                       CNN1D              R2         -0.297
#                                                          RMSE      2248.59
#                                                          MAE       1901.25
#                                                          MAPE       136.73
# Beijing-Guanyuan Air-Quality          Single Layer LSTM  R2          0.437
#                                                          RMSE        66.87
#                                                          MAE         48.19
#                                                          MAPE       185.19
#                                       Double Layer LSTM  R2          0.386
#                                                          RMSE        69.83
#                                                          MAE         50.15
#                                                          MAPE       185.63
#                                       Bidirectional LSTM R2          0.467
#                                                          RMSE        65.07
#                                                          MAE         45.65
#                                                          MAPE       174.64
#                                       CNN1D              R2         -0.383
#                                                          RMSE       104.78
#                                                          MAE         85.01
#                                                          MAPE        341.9
# Solar Generation - EnerjiSA           Single Layer LSTM  R2          0.834
#                                                          RMSE        56.19

# %%
A.to_excel('adversarial_attack_results_mtm.xlsx')
